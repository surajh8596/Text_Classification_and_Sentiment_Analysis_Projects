# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import nltk
import string
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ### Load & Read data

# %%
df=pd.read_csv('https://raw.githubusercontent.com/tkeldenich/NLP_Preprocessing/main/train.csv')
df.head()
# Out:
#           text
# 0  Forest f...
# 1  All resi...
# 2  13,000 p...
# 3  Just got...
# 4  #RockyFi...

# %%
df.shape
# Out:
# (7603, 1)

# %% [markdown]
# #### To See the "Text" columns entire content Set the column width

# %%
pd.set_option('display.max_colwidth',9999)
df.head()
# Out:
#                                                                                                                                     text
# 0                                                                                                 Forest fire near La Ronge Sask. Canada
# 1  All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected
# 2                                                                      13,000 people receive #wildfires evacuation orders in California
# 3                                               Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school
# 4                         #RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires

# %% [markdown]
# ### Cleaning the Data
# * Once the data is loaded it needs to be cleaned up, this is called preprocessing.
# * In most cases for NLP, preprocessing consists of removing non-letter characters such as “#”, “-“, “!”, numbers or even words that do not make sense or are not part of the language being analyzed.
# * Keep in mind however that for certain types of problems it can be interesting to preserve certain types of characters.
# * For example: to analyze if an email is a spam or not, we can imagine that the ‘!’ are a good indicator and therefore do not remove them during cleaning.

# %% [markdown]
# **initialize :**
# 1. **stopwords**: Which are words that appear frequently but do not bring any meaning to the sentence.
#
# example: “of”, “the”, “a”
#
# 2. **Lemmatizer**: This object allows us to preserve the root of the words so that two words having the same strain will be considered as one and the same word
#
# example: ‘neighbors’ and ‘neighborhood’ will both be changed into ‘neighbor’

# %%
stopwords = nltk.corpus.stopwords.words('english')
words = set(nltk.corpus.words.words())
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# **Afterwards we build our preprocessing function which will successively :**
# * remove the punctuation
# * remove the numbers
# * transform the sentences into a list of tokens (a list of words)
# * remove stopwords (words that don’t bring understanding)
# * lemmatize
# * remove capital letters
# * reform sentences with the remaining words

# %%
def Preprocess_listofSentence(listofSentence):
    preprocess_list = []
    for sentence in listofSentence :
        sentence_w_punct = "".join([i.lower() for i in sentence if i not in string.punctuation])
        sentence_w_num = ''.join(i for i in sentence_w_punct if not i.isdigit())
        tokenize_sentence = nltk.tokenize.word_tokenize(sentence_w_num)
        words_w_stopwords = [i for i in tokenize_sentence if i not in stopwords]
        words_lemmatize = (lemmatizer.lemmatize(w) for w in words_w_stopwords)
        sentence_clean = ' '.join(w for w in words_lemmatize if w.lower() in words or not w.isalpha())
        preprocess_list.append(sentence_clean)
    return preprocess_list

# %% [markdown]
# #### Apply above function to ''text'' column of dataset

# %%
preprocess_list = Preprocess_listofSentence(df['text'])
preprocess_list
# Out:
# ['forest fire near la canada',
#  'resident shelter place notified officer evacuation shelter place order',
#  'people receive wildfire evacuation order',
#  'got sent photo ruby smoke wildfire school',
#  'update closed direction due lake county fire wildfire',
#  'flood disaster heavy rain cause flash flooding street colorado spring area',
#  'top hill see fire wood',
#  'there emergency evacuation happening building across street',
#  'afraid tornado coming area',
#  'three people heat wave far',
#  'south getting flooded hah wait second live south gon na gon na flooding',
#  'flooding day lost count',
#  'flood bago bago',
#  'damage school bus car crash breaking',
#  'whats man',
#  'love fruit',
#  'summer lovely',
#  'car fast',
#  '',
#  'ridiculous',
#  'cool',
#  'love skiing',
#  'wonderful day',
#  '',
#  'cant eat',
#  'last week',
#  'love',
#  '',
#  'like',
#  'end',
#  'wholesale market ablaze',
#  'always try bring heavy metal',
#  'breaking flag set ablaze aba',
#  'cry set ablaze',
#  'plus side look sky last night ablaze',
#  'built much around new acquisition doubt set ablaze season',
#  'office set ablaze',
#  '\x89ûò two car set ablaze \x89ûó head st police',
#  'ablaze lord',
#  'check',
#  'outside ablaze alive dead inside',
#  'awesome time visiting head office site ablaze thanks taking care u',
#  'ablaze',
#  'set ablaze preaching hotel',
#  'follower last week know grow',
#  'west burned thousand wildfire ablaze alone',
#  'building perfect life leave street ablaze',
#  'check',
#  'first night retainer quite weird better get used wear every single night next year least',
#  'deputy man shot home set ablaze',
#  'man wife get six year jail setting ablaze niece',
#  '\x89ûó head st police superintendent salmon r',
#  'police arsonist deliberately set black church north',
#  'happy see teammate training hard gunner',
#  'flag later set ablaze office front',
#  'truck ablaze r ave outside tambo cargo section',
#  'set heart ablaze every city gift every like kiss upon lip \x89û',
#  'sky ablaze tonight filled sunset shot know peep',
#  'west burned thousand wildfire ablaze alone climate energy',
#  'revel video mean mac farewell ablaze en route',
#  'progressive greeting month student would set pen ablaze torch publication',
#  'ablaze secret k fallen sky edit mar',
#  'fire something else tinderbox clown setting hood ablaze news',
#  'ablaze buff magnitude',
#  'huge fire wholesale market ablaze',
#  'ablaze time talk go dont know make due work',
#  'cant got bicycle accident split testicle impossible father',
#  'accident w traffic moving usual',
#  'accident center lane blocked u great traffic',
#  'accident summer read advice see solicitor help',
#  'speeding among top cause teen accident car accident tee\x89û',
#  'motor vehicle accident curry near vehicle please use',
#  'live accident awareness',
#  'mile marker south vehicle accident ramp closed',
#  'sleeping pill double risk car accident',
#  'accident knew gon happen',
#  'traffic accident n mir',
#  'mile marker south vehicle accident congestion',
#  'pastor scene owner range rover',
#  'didnt get home fast wished accident truck spilt mayonnaise',
#  'horrible car accident past finally able get around thank god',
#  'wait see tell another accident',
#  'overturn interstate click youve',
#  'accident u traffic',
#  'accident motorcyclist crash car crossed median motorcycle rider traveling',
#  'accident property piner',
#  'first accident year turning onto near taxi halfway turned everyone conf\x89û',
#  'accident left lane blocked eddy stop go traffic back delay min traffic',
#  'accident property damage piner',
#  'accident',
#  'accident property th st',
#  'traffic accident injury foreman',
#  'actress accident',
#  'accident',
#  'mile backup blocking right lane exit alternate',
#  'accident life help determine option financially support life care plan ongoing treatment',
#  'breaking deadly motorcycle car accident today ill detail',
#  'accident',
#  'car even week got car accident cant drive',
#  'police previously road accident explosion',
#  'still church leader coming forward comment accident issue disciplinary',
#  'p live game',
#  'man drive effort get painful man win roger bannister',
#  'aftershock dance ices\x89û',
#  'victory bargain basement price',
#  'aftershock dance ices\x89û',
#  'nobody came second',
#  'speaking someone people end getting p also',
#  'harder conflict glorious triumph',
#  'going clay pigeon shooting cry aftershock',
#  'guess one actually want free aftershock',
#  'aftershock terrifying best roller coaster ever disclaimer',
#  'aftershock',
#  'aftershock dance ices\x89û',
#  'aftershock dance ices\x89û',
#  'aftershock dance ices\x89û',
#  'seeing issue aftershock',
#  'aftershock dance ices\x89û',
#  'aftershock dance ices\x89û',
#  'bonus minute daily habit could really improve life many already',
#  'aftershock protect profit next global financial',
#  'moment get scary roller coaster guy behind screaming bloody murder silverwood aftershock',
#  'aftershock \x89ã¢ full\x89ã¢ streaming',
#  'aftershock protect profit next global financial book',
#  'sometimes face difficulty something wrong something right',
#  'thing stand dream try belief actually possible brown',
#  'praise god ministry tell like',
#  'going die best way know avoid trap thinking something lose \x89ûò job',
#  'tried orange aftershock today life never',
#  'love',
#  'aftershock',
#  'aftershock back school kick great want thank everyone making possible great night',
#  'people say done interrupt \x89ûò shaw',
#  'first man get oyster second man get shell',
#  'anyone need pu tonight play hybrid slayer p eu',
#  'expert begin examining airplane debris found reunion island air accident expert news',
#  'strict liability context airplane accident pilot error common component aviation',
#  'lifetime odds dying airplane accident',
#  'expert begin examining airplane debris found reunion island air accident expert',
#  'theyre airplane accident theyre gon na die good job',
#  'family member bin laden airplane accident suspect',
#  'man go airplane engine accident via',
#  'horrible accident man wing airplane',
#  'airplane accident four men state government official',
#  'horrible accident man wing airplane',
#  'expert begin examining airplane debris found reunion island air accident expert wednesday\x89û',
#  'expert begin examining airplane debris found reunion island air accident expert examining',
#  'rip family member airplane accident',
#  'almost sent nude accident thank god airplane mode',
#  'might airplane accident night car wreck politics best',
#  'expert begin examining airplane debris found reunion island air accident expert',
#  'unbelievably insane man airport airplane aircraft aeroplane runway accident freaky\x89û',
#  'horrible accident man wing',
#  'horrible accident man wing airplane',
#  'bin family dead airplane crash naturally accident',
#  'pilot plane crash car festival via crash aircraft airplane pilot death accident',
#  'strict liability context airplane accident',
#  'brazil expert begin examining airplane debris found reunion island air accident',
#  'expert begin examining airplane debris found reunion island air accident expert',
#  'horrible accident man wing \x89ûïairplane\x89û\x9d can\x89ûªt believe eye \x89ûò',
#  'fletcher one victim airplane time ago accident left little bit trauma although',
#  'horrible accident man wing airplane',
#  'dont believe rip airplane accident g',
#  'expert begin examining airplane debris found reunion island air accident expert examining',
#  'airplane accident',
#  'phone look like car ship airplane accident terrible',
#  'statistically risk getting cop dying airplane accident',
#  'airplane crash house people die accident',
#  'shooting airplane accident',
#  'could drone cause airplane accident pilot worried use drone close vicinity airport',
#  'early wake call sister begging come ride ambulance hospital',
#  'twelve feared air ambulance helicopter crash',
#  'two air ambulance scene serious crash two car lorry emsne\x89û',
#  'twelve feared air ambulance helicopter crash',
#  'leading emergency service welcome new ambulance charity',
#  'anyone right there incident service halt outside shrew ambulance scene',
#  'twelve feared air ambulance helicopter crash',
#  'ambulance sprinter automatic vehicle choice compliant',
#  'new device able target destroy blood clot',
#  'crazy fight ambulance couple pit',
#  'get run ambulance lucky',
#  'news twelve feared air ambulance helicopter crash',
#  'twelve feared air ambulance helicopter crash',
#  'waiting ambulance',
#  'need ambulance good',
#  'ambulance sprinter automatic vehicle choice compliant',
#  'air ambulance helicopter crash kill nine',
#  'need medical assistance call ambulance need',
#  'em petition per hour \x89û÷minimum wage\x89ûª em ambulance',
#  'twelve feared air ambulance helicopter crash',
#  'twelve feared air ambulance helicopter crash',
#  'ambulance sprinter automatic vehicle choice compliant',
#  'ambulance sprinter automatic vehicle choice compliant',
#  'check whats parking lot said last year ambulance st',
#  'dont know way ambulance coming',
#  'twelve feared air ambulance helicopter crash',
#  'twelve feared air ambulance helicopter crash',
#  'ambulance right outside work',
#  '\x89ûïleoblakecarter dog think he ambulance httptcomglpgrrm\x89û\x9dnatasharideout',
#  'happening em ambulance dual siren and\x89û',
#  'twelve feared air ambulance helicopter crash',
#  'twelve feared air ambulance helicopter crash',
#  'twelve feared air ambulance helicopter crash',
#  'twelve feared air ambulance helicopter crash',
#  'whats police ambulance number body know',
#  'medic still clinical practice across ambulance trust',
#  'twelve feared air ambulance helicopter crash',
#  'people try ambulance passing hate',
#  'episode trunk ever mercy',
#  'shall laid bare shall kneel',
#  'baseball',
#  'previous meeting improvement',
#  'past season even ended career cant compete',
#  '',
#  'status education behalf easy street careen',
#  'die everything',
#  'good un sorry wont get',
#  'cop pull drunk driver safety second car hit train via',
#  'must',
#  'cop pull drunk driver safety second car hit train via',
#  'boom country entirely h\x89û \x89ûó',
#  'would might well thank',
#  'one thing horror',
#  'guess thats since weve spent history getting',
#  'year since people instantly aware ability annihilate whole humanity',
#  'day tryout went good minus fact stopped quickly get short ball toenail injury even',
#  'symbol peninsula',
#  'die everything',
#  'ready get game',
#  'people last night weather really thought would forecast',
#  'domain sophistication closely feat',
#  'seen priest rob came back scorpion support place astonishing gig',
#  'officially skipping getting review bummer',
#  'thus explaining case survivor godlike',
#  'completely time alive',
#  'legion survivor imperfect hybrid project quickly formed new secret cell',
#  'exactly thats match last year great brock guy who',
#  'cop pull drunk driver safety second car hit train via',
#  'army grind \x89û÷alloosh gang manure pile',
#  'wasnt completely forthright may also food coma also',
#  'fun filled bar handsome one got apart game',
#  'ball',
#  'hell fraction belief total annihilation destruction',
#  'maybe call tell sorry sold river annihilation',
#  'annihilation civilization',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'quarterstaff annihilation',
#  'world annihilation v self transformation alien attack exterminate human',
#  'planetary annihilation via',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'please sign share petition save wild horse',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'please check salt river horse help stop annihilation happen without',
#  'soul',
#  'mention major contributor annihilation',
#  'need help horse sign stand voice gilbert',
#  'reject law misguided false prophet imprison nation self annihilation',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'annihilation hour away please god allow least one full day',
#  'need die please sign petition take stand voice gilbert',
#  'need help horse sign stand voice gilbert',
#  'hey sign petition save order',
#  'stop annihilation salt river wild horse via change',
#  'he current nova tied book rider annihilation',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'please sign save',
#  'thanks count join u following annihilation zone',
#  'world annihilation v self transformation alien attack exterminate human',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'u national park service national forest stop annihilation salt river wild horse via change',
#  'gon na fight soon get',
#  'didnt survive apocalypse feel horrible poor boy child',
#  'another birthday apocalypse',
#  'adaptation watch human apocalypse film \x89û',
#  'apocalypse please',
#  'another hour august here red rover zombie apocalypse collegeradi\x89û',
#  'feel like one stage apocalypse',
#  'hot radio today whats next disease apocalypse everyone careful',
#  'apocalypse',
#  'know question interpretation sign apocalypse',
#  'r apocalypse version',
#  'apocalypse upon u',
#  'night lucky block bob apocalypse wither showcase vi\x89û',
#  'begin day one snow apocalypse',
#  'short reading apocalypse spirit angel took top enormous high mountain \x89û',
#  'imagine zombie apocalypse fighting back back heart heart conversation',
#  'video night lucky block bob apocalypse wither mo\x89û',
#  'thats planet lone audience apocalypse',
#  'dad bought look like science doc front read back actually impending apocalypse',
#  'indeed apocalypse come week know ill',
#  'go look grizzly peak right look like beginning apocalypse movie',
#  'niece would apocalypse',
#  'there storm latest apocalypse set photo via',
#  'night lucky block bob apocalypse wither showcase via',
#  'shot heart going totally give love bad name heart',
#  'play dark soul day',
#  'know go zombie take',
#  'latest storm queen apocalypse',
#  'shadow boxing apocalypse',
#  'short reading apocalypse spirit angel took top enormous high mountain',
#  'attack every time see poster freshly clean everyone apocalypse',
#  'video night lucky block bob apocalypse wither showcase',
#  'temporary kill flag fast reason',
#  'temporary kill flag fast reason',
#  'official prod',
#  'peace love',
#  'best movie youve ever seen',
#  'bed time dont wake unless revolution start',
#  'red faction full read',
#  'already know go world series',
#  'love truelove romance lith voodoo seduction astrology apocalypse pla\x89û',
#  'gon na beat hao got flawless first try',
#  'ben know there girl cant help since',
#  'id long coat hand id worn certainty bear sense occasion',
#  'phone hidden back door data mining financial',
#  'temporary kill flag fast reason',
#  'love truelove romance lith voodoo seduction astrology apocalypse planet\x89û',
#  'temporary kill flag fast reason',
#  'photo sketch based taste episode',
#  '',
#  'good luck tomorrow night get coefficient point',
#  '',
#  'another one history book thank justice department way havent income tax yr',
#  'issue major warning late escape',
#  'god kingdom heavenly rule people earth',
#  'l b entertainment lot movie die hard monkey sixth auction',
#  'let\x89ûªs talk goof guild saunders come right stage',
#  'niece gaining ability stand getting prepared toddler apocalypse',
#  'check doomsday must library collection survival via',
#  'thought yesterday saw scary hail',
#  'think already come year ago gog',
#  'sadly window ethic',
#  'averted el patron',
#  'time hour latest series blueprint extremely impressive',
#  'till',
#  'united convert soon die u',
#  'official prod',
#  'tomorrow day start',
#  'lee comedy \x89ûïleejasper working class tory prepare interestraterise\x89û\x9d',
#  'chart prove financial crisis part begun financial economic collapse track',
#  '\x89ûò issue major warning late escape russia',
#  'stage right light funny get staff',
#  'official soon',
#  'well done finger crossed tomorrow night eh',
#  'pick fan army',
#  'one direction pick fan army x',
#  'second summer pick fan army',
#  'pick fan army',
#  'pick fan army',
#  'one direction pick fan army x',
#  'seeing army first thing slightly got far',
#  'build kingdom lead army victory start g friend code',
#  'salvation army host rally reconnect father child salvation army hosting back school rally\x89û',
#  'vote v queen th round billboard',
#  'build army dog leader lion dog fight like lion',
#  'show hero review',
#  'one direction pick fan army x',
#  'infantry men dial army quartz wrist watch sport blue nylon fabric full rea\x89û',
#  'one direction pick fan army x',
#  'swiss army date woman rubber mop watch',
#  'army ki\x89û',
#  'second summer pick fan army',
#  'pick fan army',
#  'one direction pick fan army x',
#  'da one spear',
#  'one direction pick fan army',
#  'stony last hope lead army felon thus army reject army satan',
#  'army navy military japan leather watch war full read',
#  'pick fan army',
#  'pick fan army',
#  'pick fan army',
#  'pick fan army',
#  'brig gen g kaiser member river commission learn',
#  'violent country get army involved help control killing bring back peace poor people',
#  'army navy military japan leather watch war full read',
#  'army navy military japan leather watch war full read',
#  'one direction pick fan army x',
#  'one direction pick fan army',
#  'two terrorist arson ugly truth',
#  'authority say theyre struggling solve arson case like today',
#  'thousand attend rally organized peace arson attack took life',
#  'add familia arson squad',
#  'another fake hate crime burn house else new',
#  'time arson suspect linked fire caught northern',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª',
#  'sound arson',
#  'owner gay bar arson scheme',
#  'wait',
#  'arson suspect linked fire caught northern',
#  'trial date set man arson burglary',
#  'death toddler arson attack crack',
#  'teen amid protest arson attack',
#  'police hunt student arson plot police hunt student',
#  'getting thick shoulder poor girl',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª poster',
#  'arson suspect linked fire caught northern',
#  'leader hospital family arson via',
#  'owner gay bar arson scheme via',
#  'angel arson',
#  'police hunt student arson plot police hunt student',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª',
#  'owner gay bar arson scheme via',
#  'owner gay bar arson scheme',
#  'mourning notice stabbing arson victim stir \x89û÷politics grief\x89ûª',
#  'owner gay bar arson scheme',
#  'arson suspect linked fire caught northern via',
#  'couple hate crime home arson\x89û',
#  'arson suspect linked fire caught northern time',
#  'arson suspect linked fire caught northern',
#  'hate white people mo',
#  'arsonist',
#  'east bay serial arsonist',
#  'minor citation substance facing time',
#  'suspected serial arsonist',
#  'arson suspect linked fire caught northern',
#  'legal system never',
#  'u dick',
#  'arsonist also burned mattress st',
#  'arsonist',
#  'dont anything nice say come sit',
#  'vegetarian video show arsonist popular restaurant strictly vegetarian',
#  'arsonist setting many fire watch tonight\x89ûªs headline',
#  'video capture man removing flag long beach ca home burning arsonist sought',
#  'trick think nasty thing',
#  'spotlight take paradise arsonist',
#  'make',
#  'town melted ice cube arsonist',
#  'arsonist blamed blaze plastic business report',
#  '',
#  'zodiac girl feat trey produced chuck da arsonist',
#  '',
#  'east bay serial arsonist',
#  'still cant move',
#  'guess u say thinking',
#  'arsonist set vegetarian restaurant fire police',
#  'video town win arsonist',
#  'whats cracking',
#  'smoke good eat drink drive nice car wear green mink',
#  'kill got court day earl',
#  'real live go',
#  'owner gay bar arson scheme frank guilty arsonist',
#  'trusting stop terrorism like inviting arsonist join fire brigade telegraph',
#  'big top burning true story arsonist missing girl \x89û',
#  'stay civil liberty constant attack',
#  'credit inspiring rediscover',
#  'theater attack gun grabber demand \x89ûïhatchet control\x89û\x9d',
#  'breaking terror attack police post',
#  'demi really think heart attack sold million copy',
#  'scare there new version nuclear attack warning like knowing government still prepare',
#  'claim suicide mosque least',
#  'part twitter feminist try attack head',
#  'horrific attack wife news',
#  '\x89ûª blast accused heart attack',
#  'u drone attack kill suspected militant north',
#  'suspect latest theater attack psychological issue',
#  'militant attack police post injured',
#  'breaking official gave terrorist weapon used attack',
#  'government provide free treatment acid attack victim private hospital',
#  'new post new relay attack steal user credential',
#  'force raid home car attack suspect',
#  'heart attack thought goat dead dont worry rocket',
#  'gon na lie ready attack senior year',
#  'left hand side diamond graveyard shift attack defend right idiot',
#  'volleyball attack volleyball training machine set simulation',
#  'tactful yet direct response harper attack hell yeah premier',
#  'police assailant latest u movie attack homeless psychological issue',
#  'thanks damn heart attack',
#  'suspect latest u attack psychological issue',
#  'give evidence share terrorist use next',
#  'illegal alien time rape murder maria ca woman prior offense',
#  'strongly condemn attack ary news team cowardly act simply trying job',
#  'theater attack gun grabber demand \x89ûïhatchet control\x89û\x9d',
#  'fact atomic bomb little boy fat man say lot mentality went attack',
#  'everyone see ever attack dog hate group',
#  'heart disease prevention secondhand smoke',
#  'tell hit attack',
#  'attack game p vita cant wait',
#  'theater attack gun grabber demand \x89ûïhatchet control\x89û\x9d',
#  'anxiety attack',
#  'dog food',
#  'cop injured militant attack police post suspected militant police post',
#  'feel frail',
#  'feel',
#  'feeling',
#  'black men didnt make way white men black men getting',
#  'cant believe female going somehow claim offended female who medium',
#  'helicopter civilian exercise',
#  'temple mount waving flag via',
#  'temple mount waving flag via',
#  'temple mount waving flag via',
#  'unit responsible scholar youth',
#  '',
#  'temple mount waving flag via',
#  'remember time cab driver',
#  'feeling',
#  'troll pol rival never literally family literally abuse',
#  'temple mount waving flag via',
#  'temple mount waving flag via',
#  'worst person guy empathy',
#  'kelly racist trump remark view',
#  'need chill answer calmly like',
#  'temple mount waving flag via',
#  'temple mount waving flag via',
#  'temple mount waving flag via',
#  'total free',
#  'temple mount waving flag via',
#  'saw tweet feel really',
#  'temple mount waving flag via',
#  'temple mount waving flag via',
#  'temple mount waving flag via',
#  'program saw said u air plane flew uranium mine machine gun student army digging',
#  'temple mount waving flag via',
#  'thing get',
#  'temple mount waving flag via',
#  'avalanche defense match v st blue',
#  'video avalanche official video',
#  'well crash like avalanche',
#  'colorado avalanche men official colorado avalanche blue cotton hockey',
#  'frozen fury king v avalanche grand',
#  'bet didnt know kick box',
#  'little piece wrote avalanche design id appreciate greatly checked',
#  'upper deck finite made colorado avalanche mint',
#  'musician classic album cover clever music video avalanche',
#  'beautiful sweet avalanche faith rose lot frothy gyp',
#  'flame v col avalanche preseason',
#  'secret avalanche catechize inner self confidential communication respect worth',
#  'fall leaf poplar fully tumbling avalanche',
#  'saw two great punk band making original music last week check em',
#  'great performance chip saver chevy',
#  'musician classic album cover clever music video \x89û÷avalanche\x89ûª',
#  'driving avalanche car week like driving tank',
#  'free sniping avalanche x truck please favorite share',
#  'sen cant come deal avalanche',
#  'rudd green prince avalanche video',
#  'great one time deal avalanche music purchase get neal shirt',
#  'avalanche overall last season',
#  'got video rapper got song',
#  'yo flex',
#  'avalanche one world away make believing wide awake',
#  'possible new jersey avalanche next year',
#  'feat watch incredible music video avalanche',
#  'avalanche city sunset listen radio',
#  'avalanche used l v v automatic pickup truck premium b\x89û',
#  'snowflake avalanche ever feel responsible',
#  'star war power collection battle full read',
#  'civil war general battle bull run hero colonel new letter',
#  'dragon ball z battle god rotten tomato via',
#  'added video world tank battle assistant bat chat',
#  'ya boy clip v full battle',
#  'indeed fully aware battle support fight',
#  'battle bow make sure head cast vote',
#  'throwback want battle here war',
#  'baseman great metropolitan team fight battle hit way',
#  'black eye space battle star fleet ship',
#  'really taken king story trailer space battle hole',
#  'battle animation much',
#  'see battle block finally',
#  'gon get rap battle',
#  'thing battle internal v external motivation',
#  'check item got phantasmal cummerbund warcraft',
#  'young german engaged battle',
#  'video marvel v avenger battle',
#  'sigh daily battle',
#  'come realization dont attention span mass battle game painting',
#  'interested see win battle',
#  'battle goat',
#  'star war power collection battle full read',
#  'black eye space battle star fleet ship',
#  'around descendant grow via',
#  'miss son play dixie electronic green fiddle celebration sequence',
#  'news longer transport germ wake anthrax lab mishap',
#  'longer transport germ via',
#  'today longer transport pathogen',
#  'longer transport germ wake anthrax lab mishap via',
#  'stop shipping potential pathogen',
#  'longer transport pathogen wake anthrax lab mishap',
#  'longer transport germ wake anthrax lab mishap',
#  'news longer transport germ wake anthrax lab mishap say',
#  'stop transporting germ lab mishap stopped transporting certain research',
#  'longer ship potential pathogen via',
#  'lab faced secret sanction doesnt make cut',
#  'longer transport germ wake anthrax lab mishap via',
#  'house energy commerce subcommittee hold hearing oversight lab army anthrax mishap htt\x89û',
#  'willing transport research specimen potential pathogen wake anthrax lab mishap',
#  'world longer transport germ wake anthrax lab mishap',
#  'longer transport germ wake anthrax lab mishap news phone apple mobile',
#  'exclusive longer transport research specimen pathogen wake anthrax lab mishap \x89û',
#  'could problem researcher longer transport select agent via',
#  'world longer transport germ wake anthrax lab mishap',
#  'longer transport germ wake anthrax lab mishap',
#  'longer ship potential pathogen corp longer deliver package',
#  'longer ship potential pathogen business chronicle',
#  'thank longer shipping live microbe department defense',
#  'fear state repression garden',
#  'longer transport germ via',
#  'biz journal stop shipping potential pathogen',
#  'today lab faced secret sanction doesnt make cut foxnew\x89û',
#  'longer willing transport research specimen potential bioter\x89û',
#  'longer transport germ wake anthrax lab mishap via',
#  'stop shipping potential pathogen trucking',
#  'longer transport germ wake anthrax lab mishap',
#  'longer transport germ wake anthrax lab mishap',
#  'longer shipping germ',
#  'longer transport germ wake anthrax lab mishap',
#  'today lab faced secret sanction doesnt make cut foxnew\x89û',
#  'longer transport germ wake anthrax lab mishap via',
#  'safety concern grow stop transporting certain specimen research facility action',
#  'fight sir',
#  'video region targeted japan rocket launch lithium',
#  'anthrax carry extensive review lab safety pathogen handling procedure',
#  'firepower lab electronic resource fight infectious disease \x89û',
#  'take f make look id still',
#  'great deal cover got cut terrible keep good work',
#  'tale two pox body horror virus',
#  'public health epidemic outbreak homeland security news wire',
#  'creation ai climate change mass contact life wealth inequality yea weve got easy',
#  'lie trust vaccine',
#  'satan daughter shadow warrior woman aka mode p fold extra extra center',
#  'yes would think since college difficult think dispersed',
#  'volunteer participate emergency preparedness drill disaster',
#  'major newspaper running series research going n',
#  'fight sir',
#  'pretty cool list agent',
#  'government expert concerned possible organism scientist concerned',
#  'prepare u regional special pathogen treatment center infectious',
#  'support taken hostage u exist',
#  'think possibility full transformation impossible dont quite like medical mystery suck',
#  'fight sir',
#  'book future therapy technology sport sexuality diagnosis',
#  'due frat who id u another',
#  'take f make look id still',
#  'fight sir',
#  'take f make look id still',
#  'evade effort prosecute',
#  'cover nuclear activity broken least agreement',
#  'threat anthrax via',
#  'authority allay glanders fear ahead rio equestrian test event via',
#  'craving u',
#  'pool day',
#  'know anyone looking move share listing',
#  'life time crazy dey wan na blaze hate made took dedication n motivation',
#  'blaze',
#  'yes love',
#  'see virtual tour one listing fir st cannon beach listed',
#  'medium office said fire base right blaze',
#  'welcome family',
#  'love living blaze inside apt balcony',
#  'alrighty hit well blaze',
#  'blaze jay dutch slave trade',
#  'hair poverty moment need get fade weekend get',
#  'property loss wildfire nearly double blaze rage',
#  'breaking blaze east building',
#  'love',
#  'dont like babe ball fun lan',
#  'video blaze hack e',
#  'blaze covered month police thousand black interrogation facility',
#  'yo got bar even rapper',
#  'ugh blaze put calorie pizza cool',
#  'pic blaze fort look like jackass face like',
#  'look like year writing computer ahead',
#  'know',
#  'mad name dont blaze',
#  'yeah know blaze blue dont twitter drew week ago',
#  'news new page feature seek help personalize customer experience',
#  'shout blaze',
#  'video episode blaze farm beginning',
#  'property loss wildfire nearly double blaze rage fire\x89û',
#  'work yet see new vela short blaze',
#  'total tweet fail beautiful inside blaze',
#  'coming promise right',
#  'huh last year ever since people blaze back',
#  'bedroom bath sale palm ca video',
#  'yes gun',
#  'girl smooth c',
#  'say conversation agree',
#  'bright blazing fireman birthday party wedding',
#  'real radio blazing best',
#  'come blazing hot yet another city slogan',
#  'come join u tomorrow august trail diversified world marketing',
#  'morgan silver dollar gem bu cameo rev blazing m high grade full read \x89û',
#  'morgan silver dollar gem bu cameo rev blazing m high grade full read \x89û',
#  'bowl got thinking damn blazing damn long',
#  'he blazing game best stealth skill yet nothing beat silenced',
#  'bit v unfilled blazing swarm',
#  'turn radio live root blazing hit',
#  'inch dynasty',
#  'weapon master let go gun blazing',
#  'really sadly come expect',
#  'cause vocal blazing hot like weather',
#  'yr old lady town delta picture',
#  'oh heart racing temperature blazing roof fifth harmony',
#  'love',
#  'colorado word origin meaning reddish colored dummy wrong',
#  'traffic freezing cold blazing hot \x89ûò heat traffic',
#  'crazy enough run degree midday heat blazing sun place not\x89û',
#  'blazing there nothing stop',
#  'still blazing',
#  'thanks sweat bullet every time get blazing sun beating',
#  'blazing',
#  'lost word made new fan fam crazy skill beyond blessed keep blazing dude made love respect',
#  'let hot blazing fantasy escort',
#  'thank missy thought blazing hot summertime',
#  'magical bag blazing',
#  'blazing dont bother song tune',
#  'morgan silver dollar p gem bu blazing m satin rare proof like full re\x89û',
#  'blazing hot free complete month giving q',
#  'want full bitch slapping gun blazing cake throwing showdown worth wait',
#  'follow check hit single unpacked man blazing',
#  'still dont know hour physical activity blazing sun sport',
#  'way archetype bleeding readiness',
#  'threw chicken nugget sister lip bleeding',
#  'could slit throat id apologize bleeding',
#  'joe gel make stop bleeding instantly',
#  'nose bleeding last one like year ago',
#  'bleeding typewriter day far written bunch gunk',
#  'cant help hope text need talk sending hug way p bleeding death',
#  'stab back promise one bleeding',
#  'apparently bleeding people look weird well fine keep walking',
#  'eating rubbing eye hand eye bleeding tear',
#  'yea coming bleeding',
#  'look broken bleeding',
#  'hit foot toe bleeding',
#  'long see bleeding good',
#  'keep thinking stepped broken glass pun dont feel pain also bleeding',
#  'ear bleeding',
#  'hour get cab foot bleeding',
#  'cute dinner date til cam nose start bleeding',
#  'head like yo nose bleeding',
#  'bleeding silence feel violence',
#  'fell someone back hit head concrete bleeding n',
#  'yes bleeding heart liberal',
#  'already one marvel character know wear red suit bad guy cant tell he bleeding',
#  'stop bleeding',
#  'know u bleeding heart pickup artist',
#  'awesome saw bleeding pretty bad',
#  'bleeding brain dont know cause',
#  'let see good soccer bleeding yo face',
#  'bleeding wild thing running around apartment he work bar',
#  'bleeding instinct look away scratch back head',
#  'ear bleeding hate',
#  'ear bleeding',
#  'saw keep racing even bleeding',
#  'rave wedding seeing eye bleeding',
#  'say bad thing happen reason wise word gon na stop te bleeding',
#  'yo damn fast',
#  'go look w atomic bomb',
#  'cause cute active follower',
#  'see crazy line',
#  'apparently featured jazz tonight cool love',
#  'id still team even entire solar system airhead misstep',
#  'remember u like one game u dont king cup',
#  'hate people tweet receipt know wrong wont take literally desperate',
#  'think notification go check encouraging love',
#  'going dude keeping took exit side told motor',
#  'universe might actually exist scientist say sun earth',
#  'shot fired',
#  'rick',
#  'motor went flame got',
#  'dude way tusky game',
#  'night',
#  'reason',
#  'queen gambit went well control ship oh well still fun cant stop next',
#  'time ironically brought everyone hoax finally right',
#  'catfish notification',
#  'guy parking lot help wind skirt getting car',
#  'mention',
#  'st time someone phone time would blocked believe catfish',
#  'like literally',
#  'video everywhere',
#  'easy way look good ray rice',
#  'light skin guy twitter talking ugly',
#  'watched honey economy recommend conservative shoppe horror',
#  'anyone else see fireball falling earth look like plane',
#  'ye thing big still',
#  'twitter',
#  'bitch done',
#  'damn clue tried see many click could get thats',
#  'great pair like couple fighting blight',
#  'there actually theory arent reason blight dwarf one',
#  'cycling fan feel sorry world athletics blight monetary reward lot soul searching',
#  'blight',
#  'poor jack',
#  'agree knew wed going deep road found blight red aint yet',
#  'get load welfare loving blight society',
#  'new post contract blight bank wind farm',
#  'height shaker height fight blight house next door',
#  'see blight u got',
#  'carl rob blight frost snuff godly drink beer someday',
#  'kick loan effort',
#  'city program help turn blight housing development\x89û news',
#  'yes want new blight leader',
#  'release level constellation blight remix infinity',
#  'height shaker height fight blight house next door',
#  'going achieve excellence big thing develop habit little matter dont know author',
#  'sure alive blight',
#  'blight thank following',
#  'apperception bridgework blight',
#  'dotish blight car go right ahead mine',
#  'sexual woman story via',
#  'like swear secret well uncover old god slumber think there gon na another blight',
#  'double result live',
#  'first one want use community never blight park',
#  'look policy matter report county blight greening vacant land soon',
#  'put taint open gate let blight get away',
#  'theory make way much sense say dwarf may actual origin blight',
#  'refugee tragedy blight humanity shame every living',
#  'article jackman time group later estimate square mile',
#  'respecting elaboration blight lock',
#  '',
#  'every win ranked play gave special card back would cool long te\x89û',
#  'deal wait buy',
#  'new print available waiting long blizzard',
#  'give free art',
#  'order blizzard pay put nut say ball flavored boom free ice cream',
#  'blizzard rock make hump day complete',
#  'really want blizzard said guess tonight',
#  'hi believe presentation nothing like seeing live',
#  '',
#  'dolphin worship group based superstition take look tweet',
#  'let get overwatch train rolling caution though arent break',
#  '',
#  'peanut butter dough blizzard',
#  'controller arent working one second',
#  'tomorrow announcement',
#  'window get error',
#  'new expansion idea bard class holy trinity',
#  'really shocking blizzard old back wod disappointed u leaving',
#  'best thing cotton candy blizzard',
#  'lizard wizard blizzard',
#  'need',
#  'please blizzard love',
#  'blizzard would clutch',
#  'also please would much like link',
#  'act right bout get blizzard tho',
#  'control tora',
#  'first time hearthstone thought',
#  'love cotton candy blizzard',
#  'hard reset',
#  'really wan na brownie batter blizzard',
#  'call little bit blizzard',
#  'market news blizzard cognizant technology first solar',
#  'end career blizzard v knockout',
#  'biggest regret hearthstone',
#  'someone walk wan na blizzard bad',
#  'horrible moment u open look like snowy blizzard u left piece paper jean pocket',
#  '',
#  'rip blood',
#  'young blood cook gone cut',
#  'wall invincible history blood dance floor',
#  'broke fake morning blood ah hurt idea treat help pretty please',
#  'star reviewer dragon blood kindle',
#  'blood group associated gastric carcinoma say text fragile gene body',
#  'friend like blood beside u always come wounded',
#  'gone get get blood',
#  'people tattoo u donate blood receive blood well',
#  'dialysis grandpa oh lord blood make light headed',
#  'dad dont claim mean right look eye blood',
#  'automatic blood pressure monitor standard large cuff',
#  'blood pressure roof dont need extra',
#  'yeah',
#  'cant believe people mid dont high blood pressure life stressful',
#  'guy actually related blood',
#  'white people buy shoe super tight blood going foot',
#  'another day another excellent porridge seriously people blood orange porridge phenomenal',
#  'happy birthday young blood',
#  'wasnt blood',
#  'nasty blood pun intended',
#  'aint hoe blood',
#  'today getting drug tested blood drown shot document filling',
#  'man somebody got ta stop dude funny blood',
#  'wind take gypsy blood time',
#  'mad men',
#  'private thirsty blood roll',
#  'blood site para',
#  'welcome read free chapter new book encounter full hope',
#  'run blood',
#  'personal favorite include muse green day royal blood so',
#  'shed innocent blood son daughter land polluted psalm help stop sin abortion',
#  'se pone cantar cry lightning',
#  'wasnt big stab deep stab there like blood',
#  'add item everyday eating habit please research take blood\x89û',
#  'bloody hell',
#  'infected bloody ear always fun',
#  'bloody aggressive',
#  'win entire set lip crayon via go enter',
#  'hey sally sorry bloody work',
#  'listening bloody jay',
#  'version thats bloody awful well',
#  'nightmare elm street getting remade',
#  'cant bloody wait set date king\x89ûªs \x89û÷the dark tower\x89ûª',
#  'got ta try let go many bloody thing',
#  'russia may reason link b bloody invasion like bloody',
#  'bloody insomnia insomnia',
#  'tried eye ga kill ghoul damn bloody dont dare watch',
#  'suck thats bloody getting mean amends',
#  'call weekend call bloody mary time summer full new\x89û',
#  'bloody hell day havent even really done anything tired everything thought would help much',
#  'damn bloody hot',
#  'bloody sexy drool',
#  'know say side effect low really fast son product acne cream side effect bloody diarrhea',
#  'would close making money fight bloody elbow boxing',
#  'awful painting agree landscape bloody oil paint',
#  'need life sin ride till bloody end',
#  'think well bloody barking',
#  'eh hello cover bloody thigh bloody \x89ûó eh hello since expose cleavage',
#  'bloody',
#  'bloody mary sink beet juice',
#  'python date bloody far want go',
#  'meet bloody r',
#  'supposed happy day bloody hah',
#  'bloody hope said folding arm sitting back chair',
#  'wait tell college friend bloody mary drama',
#  'came kill fun video smirking remorseless killer show boasting',
#  'watched episode se bloody',
#  'steel panther shuffle mode like bloody legend',
#  'black turn bloody would rather shopping mystery',
#  'someone told soccer getting pic blown put daughter bedroom wall',
#  'mention get blown choice deactivate leave good respect choice',
#  'wow wow club blown money player like',
#  'damn got blown first inning',
#  'woke blown',
#  'aunt marge blown',
#  'yeah worth already many twitter probably blown every second',
#  'white family supposedly great value get blown horrible nuclear strike',
#  'man blown he still underground',
#  'mention blown',
#  'confederate ship blown crew read via history',
#  'moment ur win get blown creeper get flying salty',
#  'get bump approval probably he blown',
#  'truckload soldier blown nobody panic one little lion everyone mind',
#  'hey look foundation live today got blown people magazine blake',
#  'got last month went shop glad blown yet',
#  'first time tweet blown almost half day later',
#  'we\x89ûªre blown away extension nothing we\x89ûªve seen many option one',
#  'thanks stay since manor blown anyways buddy',
#  'diary pattern sand may blown away photo two flame',
#  'even though sufficiently year somehow watching utterly utterly blown away',
#  'game officially blown lady real show begin',
#  'bitten mutant mosquito ankle blown little',
#  'thing pick seat butt leprosy syndrome lateral lisp toilet rickets',
#  'blown hacker need stop',
#  'whoever video need grab someone u recognition mind blown',
#  'last week th sense get blown far good could win he huge target gone soon',
#  'like blown',
#  'dog\x89ûªs blown kennel \x89ûò bloody terrorist',
#  'turn get blown',
#  'went beaten blown next thing know ra al brought back life',
#  'as got metaphorically blown',
#  'c also help blown bottle nitroglycerin book',
#  'new lady shoulder tote handbag woman cross body bag leather fashion purse full re\x89û',
#  'new lady shoulder tote handbag woman cross body bag leather fashion purse full re\x89û',
#  'son daughter would like see going war come back body bag let republican know',
#  'ditto way feel drank vodka ice would body bag',
#  'handbag genuine mulberry cross body messenger bag dark oak soft buffalo leather å£end date w',
#  'monogram limited edition clutch cross body bag full read',
#  'monogram limited edition clutch cross body bag full read',
#  'monogram shoulder bag cross body bag',
#  'check healthy back bag shoulder cross body khaki tan beige nylon',
#  'photo bath body work cosmetic bag periwinkle blue copper piping along top four corner',
#  'new lady shoulder tote handbag woman cross body bag leather fashion purse full re\x89û',
#  'new summer long thin body bag hip word skirt blue',
#  'å¤ new lady shoulder tote handbag leather hobo purse cross body bag woman en\x89û',
#  'wan na fight meet cage better find dealing end body bag',
#  'new lady shoulder tote handbag leather hobo purse cross body bag woman full read\x89û',
#  'brown cross body shoulder bag monogram full read\x89û',
#  'check vintage floral fabric shoulder cross body bag brown leather strap',
#  'new lady shoulder tote handbag leather hobo purse cross body bag woman',
#  'new summer long thin body bag hip word skirt blue',
#  'new lady shoulder tote handbag leather hobo purse cross body bag woman en\x89û',
#  'monogram limited edition clutch cross body bag full read',
#  'new woman handbag leather lady shoulder tote cross body bag large satchel full re\x89û',
#  'new lady shoulder tote handbag leather hobo purse cross body bag woman',
#  'one day heart gone get body bag',
#  'handbag fashion style authentic pochette shoulder cross body bag\x89û',
#  'new lady shoulder tote handbag leather hobo purse cross body bag woman',
#  'handbag fashion style vintage coach purse camera bag cross body bid \x89û',
#  'genuine leather man bag messenger fit tablet case cross body air full rea\x89û',
#  'monogram limited edition clutch cross body bag full read',
#  'new lady shoulder tote handbag leather hobo purse cross body bag woman',
#  'fam leave body bag',
#  'new lady shoulder tote handbag leather hobo purse cross body bag woman full read\x89û',
#  'saying theyre lucky go home family put body bag',
#  'oh bagging body saying going get rose',
#  'bagging body smoking hot',
#  'drake really body bagging meek',
#  'drake killing dude tea bagging dead body point',
#  'wreck league ball drake level body bagging like career nothing',
#  'tough canada north meek acting like bitch drake body bagging as track',
#  'body bagging',
#  'skimmed twitter body bagging',
#  'g body bagging lyrically',
#  'straight body bagging',
#  'body bagging bitch',
#  'better feeling seeing stage day one year friendship still body bagging together',
#  'problem game body bagging',
#  'body bagging post score',
#  'let bagging body begin aint yet shouldnt bad',
#  'drake straight body bagging meek stage',
#  ...]

# %%
# check whether function fine or not
print('Original sentence : '+df['text'][4])
print('Cleaned sentence : '+preprocess_list[4])
# Out:
# Original sentence : #RockyFire Update => California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires
# Cleaned sentence : update closed direction due lake county fire wildfire

# %% [markdown]
# ### Encoding Text
# * Encoding is an essential step in Machine Learning.
# * It allows us to transform the text data into numbers that the machine can interpret and understand.
# * There are different types of encoding,
#     1. One Hot Encoding
#     2. Label Encoding etc

# %% [markdown]
# ### One-Hot Encoding
# * One-Hot consists in creating a dictionary with every words that appear in our cleaned sentences.
# * This dictionary is in fact a table where each column represents a word and each row represents a sentence.
# * If such a word appears in such a sentence, we put a 1 in the element of the table, otherwise we put a 0.
# * We will thus have an array composed only of 0 and 1.
# * The only disadvantage of One-Hot Encoding is that we lose the hierarchy, the order of the words. we lose the context, the meaning of the sentence and in theory this should impoverish the results of our model.
#
# **To realize the One-Hot Encoding in Python, we initialize the dictionary with the CountVectorizer() function of the Sklearn library. Then we use the fit_transform() function on our preprocessed data.**

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(preprocess_list)
X.toarray()[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ##### See which features or columns we have

# %%
vectorizer.get_feature_names()
# Out:
# ['aa',
#  'aal',
#  'aba',
#  'abandon',
#  'abandoned',
#  'ability',
#  'abject',
#  'ablaze',
#  'able',
#  'aboard',
#  'abomination',
#  'abortion',
#  'abouts',
#  'absence',
#  'absolute',
#  'absolutely',
#  'abstract',
#  'absurd',
#  'absurdly',
#  'abuse',
#  'accept',
#  'access',
#  'accident',
#  'accidentally',
#  'accidently',
#  'accidents',
#  'according',
#  'accordingly',
#  'account',
#  'accountable',
#  'accuracy',
#  'accused',
#  'accustomed',
#  'ace',
#  'achieve',
#  'achievement',
#  'aching',
#  'acid',
#  'acids',
#  'acne',
#  'acoustic',
#  'acquiesce',
#  'acquire',
#  'acquired',
#  'acquisition',
#  'acre',
#  'acronym',
#  'across',
#  'acrylic',
#  'act',
#  'actin',
#  'acting',
#  'action',
#  'activate',
#  'active',
#  'actively',
#  'activist',
#  'activity',
#  'actor',
#  'actress',
#  'actual',
#  'actually',
#  'acute',
#  'ad',
#  'adaptation',
#  'add',
#  'added',
#  'addict',
#  'addiction',
#  'addition',
#  'address',
#  'adjust',
#  'adjustable',
#  'adjuster',
#  'administration',
#  'administrative',
#  'admit',
#  'adopt',
#  'adoption',
#  'adoptive',
#  'adorable',
#  'adult',
#  'advance',
#  'advanced',
#  'advantage',
#  'adventure',
#  'adverse',
#  'advertise',
#  'advice',
#  'advised',
#  'advisory',
#  'aeroplane',
#  'aesthetic',
#  'affair',
#  'affect',
#  'affected',
#  'affecting',
#  'affiliate',
#  'affiliation',
#  'affliction',
#  'afloat',
#  'afraid',
#  'afterhours',
#  'afterlife',
#  'aftermath',
#  'afternoon',
#  'aftershock',
#  'afterwards',
#  'agalloch',
#  'age',
#  'agency',
#  'agent',
#  'aggression',
#  'aggressive',
#  'aggressively',
#  'agnus',
#  'ago',
#  'agony',
#  'agree',
#  'agreed',
#  'agreement',
#  'ah',
#  'ahead',
#  'ai',
#  'aid',
#  'aim',
#  'aimlessly',
#  'aint',
#  'air',
#  'aircraft',
#  'airhead',
#  'airing',
#  'airlift',
#  'airplane',
#  'airport',
#  'aisle',
#  'ak',
#  'aka',
#  'al',
#  'ala',
#  'alameda',
#  'alarm',
#  'alarmed',
#  'alarming',
#  'alarmingly',
#  'alaska',
#  'alba',
#  'albeit',
#  'album',
#  'alchemist',
#  'alcohol',
#  'alec',
#  'alert',
#  'algae',
#  'alien',
#  'align',
#  'alive',
#  'allay',
#  'allegation',
#  'allegedly',
#  'allegiance',
#  'allergic',
#  'alley',
#  'alliance',
#  'allied',
#  'alloosh',
#  'allotment',
#  'allow',
#  'alloy',
#  'ally',
#  'almighty',
#  'almost',
#  'alone',
#  'along',
#  'alp',
#  'alpha',
#  'already',
#  'alright',
#  'alrighty',
#  'also',
#  'alt',
#  'alternate',
#  'alternative',
#  'although',
#  'aluminum',
#  'always',
#  'ama',
#  'amateur',
#  'amazed',
#  'amazing',
#  'amazon',
#  'amber',
#  'ambition',
#  'ambulance',
#  'amen',
#  'amends',
#  'america',
#  'amid',
#  'amino',
#  'amman',
#  'among',
#  'amongst',
#  'amplifier',
#  'an',
#  'ana',
#  'analysis',
#  'anarchy',
#  'anatomy',
#  'anchor',
#  'anchorage',
#  'ancient',
#  'and',
#  'android',
#  'anew',
#  'angel',
#  'angelriveralib',
#  'anger',
#  'angioplasty',
#  'angry',
#  'ani',
#  'animal',
#  'animation',
#  'anime',
#  'ankle',
#  'anna',
#  'annihilate',
#  'annihilation',
#  'anniversary',
#  'announce',
#  'announcement',
#  'annoying',
#  'annual',
#  'anonymous',
#  'another',
#  'answer',
#  'ant',
#  'ante',
#  'anthelmintic',
#  'anthology',
#  'anthrax',
#  'anti',
#  'antichrist',
#  'antifeminist',
#  'anxiety',
#  'anxious',
#  'anybody',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'apartment',
#  'apiece',
#  'apocalypse',
#  'apocalyptic',
#  'apologize',
#  'apology',
#  'appalling',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appease',
#  'apperception',
#  'appetite',
#  'applaud',
#  'apple',
#  'application',
#  'applied',
#  'apply',
#  'appointment',
#  'appraisal',
#  'appreciate',
#  'approach',
#  'approaching',
#  'appropriate',
#  'appropriation',
#  'approval',
#  'apropos',
#  'apt',
#  'aquarium',
#  'ar',
#  'ara',
#  'arcade',
#  'archetype',
#  'architect',
#  'architecture',
#  'are',
#  'area',
#  'areal',
#  'aren',
#  'arena',
#  'arent',
#  'argue',
#  'argument',
#  'ari',
#  'ariz',
#  'arm',
#  'armed',
#  'armory',
#  'army',
#  'around',
#  'arrest',
#  'arrival',
#  'arrive',
#  'arrogant',
#  'arse',
#  'arsenal',
#  'arson',
#  'arsonist',
#  'art',
#  'article',
#  'artificial',
#  'artillery',
#  'artist',
#  'ary',
#  'as',
#  'ascend',
#  'ash',
#  'aside',
#  'ask',
#  'asleep',
#  'aspect',
#  'asphalt',
#  'aspiring',
#  'ass',
#  'assailant',
#  'assassins',
#  'assault',
#  'assembly',
#  'assertative',
#  'assessment',
#  'asset',
#  'assistance',
#  'assistant',
#  'associated',
#  'association',
#  'assume',
#  'assured',
#  'astonishing',
#  'astounding',
#  'astrakhan',
#  'astrologian',
#  'astrology',
#  'asylum',
#  'at',
#  'ate',
#  'atheistic',
#  'athlete',
#  'athletics',
#  'atlantic',
#  'atlas',
#  'atmosphere',
#  'atmospheric',
#  'atom',
#  'atomic',
#  'attached',
#  'attack',
#  'attempt',
#  'attend',
#  'attendance',
#  'attention',
#  'attic',
#  'attitude',
#  'attraction',
#  'attractive',
#  'auburn',
#  'auction',
#  'audience',
#  'audio',
#  'audit',
#  'august',
#  'aunt',
#  'aurora',
#  'australia',
#  'authentic',
#  'author',
#  'authority',
#  'autism',
#  'autistic',
#  'auto',
#  'autobiography',
#  'automatic',
#  'autumn',
#  'ava',
#  'available',
#  'avalanche',
#  'ave',
#  'avenger',
#  'avenue',
#  'average',
#  'avert',
#  'averted',
#  'aviation',
#  'avoid',
#  'aw',
#  'await',
#  'awake',
#  'awakening',
#  'award',
#  'aware',
#  'awareness',
#  'awash',
#  'away',
#  'awesome',
#  'awful',
#  'awkward',
#  'awn',
#  'ay',
#  'ba',
#  'babe',
#  'baby',
#  'back',
#  'background',
#  'backing',
#  'backlash',
#  'backup',
#  'bacteria',
#  'bad',
#  'badge',
#  'badges',
#  'badly',
#  'badu',
#  'bae',
#  'baffle',
#  'baffling',
#  'bag',
#  'baggage',
#  'bagged',
#  'bagging',
#  'bago',
#  'bags',
#  'bah',
#  'bail',
#  'bait',
#  'bake',
#  'baked',
#  'baking',
#  'bal',
#  'balance',
#  'balcony',
#  'bali',
#  'ball',
#  'ban',
#  'banana',
#  'band',
#  'bang',
#  'bank',
#  'banking',
#  'bannister',
#  'banquet',
#  'bar',
#  'barbaric',
#  'barber',
#  'barcelona',
#  'bard',
#  'bardo',
#  'bare',
#  'barely',
#  'bargain',
#  'bark',
#  'barking',
#  'barn',
#  'barra',
#  'barrack',
#  'barrier',
#  'barring',
#  'barry',
#  'bartender',
#  'basalt',
#  'base',
#  'baseball',
#  'based',
#  'baseman',
#  'basement',
#  'bash',
#  'basic',
#  'basically',
#  'basis',
#  'bask',
#  'basket',
#  'bass',
#  'bastard',
#  'bat',
#  'bath',
#  'bathe',
#  'bathroom',
#  'batter',
#  'battered',
#  'battery',
#  'batting',
#  'battle',
#  'battlefield',
#  'battleship',
#  'bay',
#  'bayonet',
#  'be',
#  'beach',
#  'beached',
#  'beacon',
#  'beam',
#  'bean',
#  'bear',
#  'beard',
#  'beast',
#  'beastly',
#  'beat',
#  'beaten',
#  'beating',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'beckoning',
#  'become',
#  'becomes',
#  'becoming',
#  'bed',
#  'bedding',
#  'bedroom',
#  'bee',
#  'beef',
#  'beer',
#  'beet',
#  'beetroot',
#  'begging',
#  'begin',
#  'beginner',
#  'beginning',
#  'begun',
#  'behalf',
#  'behavior',
#  'behaviour',
#  'behead',
#  'behind',
#  'behold',
#  'beige',
#  'belie',
#  'belief',
#  'believe',
#  'believing',
#  'bell',
#  'belle',
#  'belligerent',
#  'belly',
#  'belt',
#  'belter',
#  'beluga',
#  'ben',
#  'bend',
#  'bene',
#  'beneath',
#  'benedict',
#  'benediction',
#  'benefit',
#  'benjamin',
#  'berlin',
#  'berry',
#  'beside',
#  'besides',
#  'besieged',
#  'best',
#  'bet',
#  'beth',
#  'better',
#  'betting',
#  'beware',
#  'beyond',
#  'bias',
#  'bicentennial',
#  'bicycle',
#  'bicyclist',
#  'bid',
#  'big',
#  'bigamist',
#  'bigger',
#  'biggest',
#  'bike',
#  'bilic',
#  'bilingual',
#  'bill',
#  'billboard',
#  'billing',
#  'billion',
#  'billionaire',
#  'billy',
#  'bin',
#  'bind',
#  'biological',
#  'bioter',
#  'bird',
#  'birth',
#  'birthday',
#  'bistro',
#  'bit',
#  'bitch',
#  'bite',
#  'biting',
#  'bitten',
#  'bitter',
#  'biz',
#  'black',
#  'blackberry',
#  'blacken',
#  'blackmail',
#  'blah',
#  'blake',
#  'blame',
#  'blamed',
#  'blaming',
#  'bland',
#  'blanket',
#  'blast',
#  'blasting',
#  'blaze',
#  'blazing',
#  'bleacher',
#  'bleed',
#  'bleeding',
#  'blending',
#  'bless',
#  'blessed',
#  'blessing',
#  'blight',
#  'blind',
#  'blink',
#  'blinked',
#  'blinker',
#  'bliss',
#  'blitz',
#  'blizzard',
#  'block',
#  'blockage',
#  'blocked',
#  'blocking',
#  'bloke',
#  'blonde',
#  'blood',
#  'bloody',
#  'bloom',
#  'blossom',
#  'blow',
#  'blower',
#  'blowing',
#  'blown',
#  'blowout',
#  'blubber',
#  'blue',
#  'bluebell',
#  'blueprint',
#  'bluff',
#  'blunt',
#  'bn',
#  'bo',
#  'board',
#  'boarding',
#  'boasting',
#  'boat',
#  'bob',
#  'bobble',
#  'bobcat',
#  'bod',
#  'bodied',
#  'body',
#  'bolster',
#  'bolt',
#  'bomb',
#  'bombed',
#  'bomber',
#  'bon',
#  'bone',
#  'bong',
#  'bonsai',
#  'bonus',
#  'boob',
#  'book',
#  'bookmobile',
#  'boom',
#  'boost',
#  'boot',
#  'booth',
#  'booty',
#  'booze',
#  'border',
#  'borderland',
#  'bore',
#  'boring',
#  'born',
#  'borrower',
#  'boston',
#  'bot',
#  'bother',
#  'bottle',
#  'bottling',
#  'bottom',
#  'bought',
#  'boulder',
#  'bounce',
#  'bound',
#  'boundary',
#  'bounty',
#  'bout',
#  'bovine',
#  'bow',
#  'bowe',
#  'bowery',
#  'bowknot',
#  'bowl',
#  'bowling',
#  'box',
#  'boxer',
#  'boxing',
#  'boy',
#  'brace',
#  'bracelet',
#  'bracing',
#  'bracket',
#  'brain',
#  'brainless',
#  'brake',
#  'branch',
#  'brand',
#  'brant',
#  'brass',
#  'brasswork',
#  'brave',
#  'bravery',
#  'brazil',
#  'breach',
#  'bread',
#  'break',
#  'breakdown',
#  'breakfast',
#  'breaking',
#  'breast',
#  'breath',
#  'breathe',
#  'breathing',
#  'bred',
#  'breed',
#  'breeder',
#  'brewer',
#  'brewing',
#  'brick',
#  'bridal',
#  'bride',
#  'bridge',
#  'bridgework',
#  'brief',
#  'briefing',
#  'brig',
#  'brigade',
#  'bright',
#  'brightening',
#  'brightly',
#  'brilliant',
#  'bring',
#  'brisk',
#  'brit',
#  'british',
#  'broad',
#  'broadcast',
#  'broadly',
#  'broadway',
#  'brochure',
#  'brock',
#  'broke',
#  'broken',
#  'brother',
#  'brought',
#  'brown',
#  'browner',
#  'brownie',
#  'browser',
#  'browsing',
#  'bruise',
#  'brunette',
#  'brunt',
#  'brush',
#  'brut',
#  'brutal',
#  'brutality',
#  'brutally',
#  'bu',
#  'bubble',
#  'buck',
#  'buckle',
#  'bud',
#  'buddy',
#  'budget',
#  'buff',
#  'buffalo',
#  'buffer',
#  'buffet',
#  'bug',
#  'build',
#  'builder',
#  'building',
#  'buildings',
#  'buildup',
#  'built',
#  'bull',
#  'bullet',
#  'bulletin',
#  'bulletproof',
#  'bullets',
#  'bully',
#  'bummer',
#  'bump',
#  'bumper',
#  'bunch',
#  'bundle',
#  'bundy',
#  'bunting',
#  'burglar',
#  'burglary',
#  'buried',
#  'burn',
#  'burned',
#  'burner',
#  'burning',
#  'burnt',
#  'burp',
#  'burst',
#  'burton',
#  'bury',
#  'bus',
#  'bush',
#  'business',
#  'businessman',
#  'bust',
#  'busted',
#  'busy',
#  'butch',
#  'butt',
#  'butter',
#  'button',
#  'buy',
#  'by',
#  'bye',
#  'bypass',
#  'ca',
#  'cab',
#  'cabbage',
#  'cabin',
#  'cable',
#  'cabling',
#  'cachet',
#  'cafì',
#  'cage',
#  'cain',
#  'cake',
#  'cal',
#  'calais',
#  'calamity',
#  'call',
#  'calling',
#  'calm',
#  'calmly',
#  'calorie',
#  'calumet',
#  'cam',
#  'came',
#  'cameo',
#  'camera',
#  'camilla',
#  'camp',
#  'campaign',
#  'camper',
#  'campfire',
#  'campground',
#  'campus',
#  'can',
#  'canada',
#  'canal',
#  'cancel',
#  'cancer',
#  'candidate',
#  'candle',
#  'candy',
#  'cannibalism',
#  'cannon',
#  'canoe',
#  'cant',
#  'cantar',
#  'canvas',
#  'canyon',
#  'cap',
#  'capable',
#  'capacity',
#  'cape',
#  'capital',
#  'capitalism',
#  'capitalist',
#  'capitulation',
#  'capsize',
#  'captain',
#  'caption',
#  'captive',
#  'captivity',
#  'captor',
#  'capture',
#  'car',
#  'caravan',
#  'carcinoma',
#  'card',
#  'cardboard',
#  'care',
#  'careen',
#  'career',
#  'careful',
#  'carefully',
#  'careless',
#  'carful',
#  'cargo',
#  'carl',
#  'carnage',
#  'caroline',
#  'carpet',
#  'carr',
#  'carriage',
#  'carried',
#  'carry',
#  'carrying',
#  'cart',
#  'cartel',
#  'cartoon',
#  'cartridge',
#  'cascade',
#  'case',
#  'cash',
#  'casing',
#  'casino',
#  'cast',
#  'casting',
#  'castle',
#  'casual',
#  'casually',
#  'casualties',
#  'casualty',
#  'cat',
#  'cataclysmic',
#  'catalogue',
#  'catastrophe',
#  'catastrophic',
#  'catch',
#  'catcher',
#  'catching',
#  'catechize',
#  'catfish',
#  'caught',
#  'causation',
#  'cause',
#  'causing',
#  'caution',
#  'cautious',
#  'cave',
#  'ce',
#  'cee',
#  'celebration',
#  'celebrity',
#  'celestial',
#  'cell',
#  'cement',
#  'censor',
#  'censorship',
#  'census',
#  'center',
#  'centipede',
#  'central',
#  'cereal',
#  'cern',
#  'cerography',
#  'certain',
#  'certainly',
#  'certainty',
#  'certificate',
#  'certified',
#  'cervix',
#  'cest',
#  'chain',
#  'chair',
#  'chairman',
#  'challenge',
#  'champ',
#  'champagne',
#  'champaign',
#  'champion',
#  'championship',
#  'chance',
#  'change',
#  'channel',
#  'chaos',
#  'chapter',
#  'character',
#  'charcoal',
#  'charge',
#  'charger',
#  'charging',
#  'charity',
#  'charming',
#  ...]
